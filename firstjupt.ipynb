# %%
#creating the covid affected visualization

from matplotlib import pyplot as plt
coronapatients = [123453, 345636, 246733, 456735, 578833, 466673, 45733, 559504, 96477, 678347]
country = ['USA', 'India', 'Italy', 'Nepal', 'Brazil', 'Russia', 'China', 'Iran', 'Srilanka', 'UK']
plt.bar(country,coronapatients,color="green",label="Corona affected people")
plt.legend()
plt.title("corona affected countries")
plt.xlabel("country Name")
plt.ylabel("Affected people")
plt.show()

# %%
#Affected on the basis of countries
from matplotlib import pyplot as plt
import pandas as pd
from pandas import read_csv

data = pd.read_csv('dash.csv',index_col='Date')
data.plot(kind='bar')
plt.title("corona dashboard -Nepal")
plt.ylabel("People")
plt.xlabel("Date")
plt.show()

# %%
#seeing the age of the Male and Female who got Corona
from matplotlib import pyplot as plt
Male = [23, 21, 13, 10, 18, 17, 40, 35, 27, 58, 65, 72, 89]
Female = [32, 42, 21, 12, 11, 15, 57, 42, 77, 60, 81,29, 22]
plt.ylabel('No. of people')
plt.xlabel('Age')
plt.title('Corona Dashboard _ Age wise in Nepal')
plt.hist([Male,Female],bins=[0, 15, 30, 45, 60, 75, 90],color=['Green', 'Blue'],label=['Male','Female'])
plt.show()

# %%
#visualizing the score on reading and writing on math

from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv('data.csv')
df.dropna(axis = 1,inplace = True)
df.head()



plt.plot([1,3,2,4,1]) #line plot
plt.show()

# %%
#scatter plot
plt.scatter(x = df['math score'], y = df['writing score'])
plt.show()

# %%
plt.hist(df['reading score'], bins = 5)
plt.show()

# %%
#Box Plot
plt.boxplot(df['writing score'])
plt.show()

# %%
#Adding labels and Title
plt.scatter(x = df['math score'], y = df['writing score'], color = 'blue')
plt.xlabel('score in math')
plt.ylabel('score in writing')
plt.title('scatter plot between two scores')
plt.show()

# %%
plt.figure(figsize=(16,7))
plt.scatter(x = df['math score'], y = df['writing score'], color = 'red')
plt.xlabel('score in math')
plt.ylabel('score in writing')
plt.title('scatter plot between two scores')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = df['math score'], y = df['writing score'])
plt.scatter(x = df['math score'], y = df['reading score'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = df['math score'], y = df['writing score'], alpha = 0.5, label = 'math and writing score')
plt.scatter(x = df['math score'], y = df['reading score'], alpha = 0.5, label = 'math and readiing score')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x, y: np.sin(x) * np.cos(y)
x = np.linspace(-3,2,75)
y = np.linspace(-3,2,75)
X, Y = np.meshgrid(x, y)

F = f(X, Y)
plt.contour(X, Y, F, 15)
plt.show()

# %%
#creating the 3d data visulization
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

f = lambda x, y: np.sin(x) * np.cos(y)
x = np.linspace(-3,2,75)
y = np.linspace(-3,2,75)
X, Y = np.meshgrid(x, y)
F = f(X, Y)

fig = plt.figure(figsize = [12, 8])
ax = fig.gca(projection = '3d') #setup the 3d plot
ax.plot_surface(X, Y, F,)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8308\535278285.py:14: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d') #setup the 3d plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

f = lambda x, y: np.sin(x) * np.cos(y)
x = np.linspace(-3,2,75)
y = np.linspace(-3,2,75)
X, Y = np.meshgrid(x, y)
F = f(X, Y)

fig = plt.figure(figsize = [12, 8])
ax = fig.gca(projection = '3d') #setup the 3d plot
ax.plot_surface(X, Y, F, cmap=cm.coolwarm)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8308\758057915.py:13: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d') #setup the 3d plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

f = lambda x, y: np.sin(x) * np.cos(y)
x = np.linspace(-3,2,75)
y = np.linspace(-3,2,75)
X, Y = np.meshgrid(x, y)
F = f(X, Y)

def plotter(E, A):
   fig = plt.figure(figsize = [12, 8])
   ax = fig.gca(projection = '3d')
   ax.plot_surface(X, Y, F, cmap=cm.coolwarm)
   ax.view_init(elev=E, azim=A)
   plt.show()

#plotter(30,15)

from ipywidgets import interactive
iplot = interactive(plotter,
                   E = (-90,90,5),
                   A = (-90,90,5)
                   )
iplot
# Out:
# interactive(children=(IntSlider(value=0, description='E', max=90, min=-90, step=5), IntSlider(value=0, descrip…
